# %% [markdown]
# <a href="https://colab.research.google.com/github/AnisAfiqah13/STQD6014-DATA-SCIENCE/blob/main/AnisAfiqah_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NAME: NUR ANIS AFIQAH BINTI MOHD KHAIRUL ANUAR**
#
# **ID: P132838**
#
# **IMPORT BANK MODULE**

# %%
# Mount to Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Upload a file called anisafiqah_bankmodule.py
from google.colab import files
files.upload()

from anisafiqah_bankmodule import BankAccount
from anisafiqah_bankmodule import ChildBankAccount

# Example usage:
parent_account = BankAccount("Anuar_74", "Mohd Khairul Anuar", "741218036666", "Kota Bharu", "0179998889", 1000) #initial savings set to RM1000
child_account = ChildBankAccount("Anis_98", "Nur Anis Afiqah", "980913036666", "Kota Bharu", "0147776667", 100, parent_account) #initial savings set to RM100

#Scenario 1: parent account deposits RM1000 and child account deposit RM100
print(parent_account.deposit(1000))
print(child_account.deposit(100))
print("\n........................\n")
#Scenario 2: parent account withdraws RM2000 and child account withdraw RM50
print(parent_account.withdraw(2000))
print(child_account.withdraw(50))
print("\n........................\n")
#Scenario 3: check parent info for child account
print(child_account.get_parent_info())
print("\n........................\n")
#Scenario 4: parent account withdraws money and closes the account
print(parent_account.withdraw(1000))
print(parent_account.close_account())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      <input type="file" id="files-6d26cd55-1a50-4418-8631-42a01ac075e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d26cd55-1a50-4418-8631-42a01ac075e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
