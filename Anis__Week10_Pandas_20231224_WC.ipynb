# %% [markdown]
# <a href="https://colab.research.google.com/github/AnisAfiqah13/STQD6014-DATA-SCIENCE/blob/main/Anis__Week10_Pandas_20231224_WC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Week10:Data Manipulation with Pandas**
# Details of codes used in this notebook can be found in this textbook: **Python Data Science Handbook by Jake VanderPlas: https://tinyurl.com/33ha6r7s**

# %% [markdown]
# ### **Import Pandas and NumPy library**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### **Pandas Series Object - One dimensional array of indexed data**

# %%
# Pandas series wraps both a sequence of values and a sequence of indices
data = pd.Series([.25, .5, .75, 1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
# Check data values
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
# Check data index
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# Extract using index
data[1]
# Out:
# 0.5

# %%
# Extract using index - multiple element
#implicit indexing - inclusive and exclusive rules to follow
data[1:3] #3 is exclusive
# Out:
# b    0.50
# c    0.75
# dtype: float64

# %%
# Index need not be an integer
# Index can take on string format as well
# We can define indexes ourselves

data = pd.Series([.25, .5, .75, 1.0],
                 index = ['a','b','c','bernard'])
data
# Out:
# a          0.25
# b          0.50
# c          0.75
# bernard    1.00
# dtype: float64

# %%
# Extract data using index
# Explicit indexing
data['a':'bernard']
# Out:
# a          0.25
# b          0.50
# c          0.75
# bernard    1.00
# dtype: float64

# %% [markdown]
# ### **Series as specialized dictionary**

# %%
# Create a dictionary
pop_dict = {'California': 38332521,
            'Texas': 26448193,
            'New York': 19651127,
            'Florida': 19552860,
            'Illinois': 12882135}

# %%
# Convert to pandas Series
population = pd.Series(pop_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
# Convert to pandas dataframe
pd.DataFrame(population)
# Out:
#                    0
# California  38332521
# Texas       26448193
# New York    19651127
# Florida     19552860
# Illinois    12882135

# %%
# Extract using index - use row name to extract #always use square bracket
population['California']
# Out:
# 38332521

# %%
# Extract using index - multiple row names
population['California':'New York']
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# dtype: int64

# %% [markdown]
# # ***To extract from Pandas DataFrame, you need to use square bracket "[ ]"***

# %% [markdown]
# ### **The Pandas DataFrame Object**
# DataFrame is a **two-dimensional array** with both flexible row indices and flexible column names

# %%
# A dictionary
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
               'Florida': 170312, 'Illinois': 149995}

# %%
# Convert to pd Series -> area
area = pd.Series(area_dict)

# %%
# Output area content
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
#check data type
type(area)
# Out:
# pandas.core.series.Series

# %%
# Output population content
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
#check data tye of population
type(population)
# Out:
# pandas.core.series.Series

# %%
# Create a pandas DataFrame using population and area Series data -> states
# Use dictionary type to create the DataFrame -> use curly bracket
states = pd.DataFrame({'Populasi':population,
                       'Keluasan':area})
states
# Out:
#             Populasi  Keluasan
# California  38332521    423967
# Texas       26448193    695662
# New York    19651127    141297
# Florida     19552860    170312
# Illinois    12882135    149995

# %%
# Extract using index
#show difference between single bracket vs double bracket
print(states['Populasi']) #single bracket -> returns a Series format (its original format)
print('\n.................\n')
states[['Populasi']] #doule bracket -> keep the DatFrame format
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# Name: Populasi, dtype: int64
#
# .................
#             Populasi
# California  38332521
# Texas       26448193
# New York    19651127
# Florida     19552860
# Illinois    12882135

# %%
# Pandas DataFrame formed from 'area' Series
# Without giving the column name -> Pandas will assign numerical value as a column name
# column name becomes 0
pd.DataFrame(area)
# Out:
#                  0
# California  423967
# Texas       695662
# New York    141297
# Florida     170312
# Illinois    149995

# %%
# Give and explicit name to the column name
pd.DataFrame(area,columns=['Keluasan(m^2)'])
# Out:
#             Keluasan(m^2)
# California         423967
# Texas              695662
# New York           141297
# Florida            170312
# Illinois           149995

# %%
# Lists formed from a list of dictionaries
data = [{'a': 1, 'b': 2 * i}
        for i in range(3)]
type(data)
# Out:
# list

# %%
# Pandas DataFrame
pd.DataFrame(data)
# Out:
#    a  b
# 0  1  0
# 1  1  2
# 2  1  4

# %%
# Pandas data frame with missing data
# NaN is a special floating-point value
pd.DataFrame([{'a':1,'b':2},{'b':3,'c':4}])
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  4.0

# %%
# Form pandas dataframe using a two-dimensional NumPy array
pd.DataFrame(np.random.rand(3, 2), # dimension of 3x2
             columns=['foo', 'bar'],
             index=['a', 'b', 'c'])
# Out:
#         foo       bar
# a  0.309345  0.908019
# b  0.905354  0.448986
# c  0.022757  0.160489

# %%
# Challenge
# Create a 3 x 5 data frame
trial = pd.DataFrame(np.random.rand(3, 5), # dimension of 3x5
             columns=['foo', 'bar','Ali','Abu','Ahmad'],
             index=['a', 'b', 'c'])
trial
# Out:
#         foo       bar       Ali       Abu     Ahmad
# a  0.053032  0.158792  0.137399  0.762381  0.006266
# b  0.742821  0.272027  0.150535  0.699412  0.264621
# c  0.584075  0.531675  0.780485  0.703358  0.467687

# %%
# Add column # 6 with standard normal data
# important for final exam
trial['bernard'] = np.random.standard_normal(3)
trial
# Out:
#         foo       bar       Ali       Abu     Ahmad   bernard
# a  0.053032  0.158792  0.137399  0.762381  0.006266  0.326140
# b  0.742821  0.272027  0.150535  0.699412  0.264621 -0.347303
# c  0.584075  0.531675  0.780485  0.703358  0.467687 -2.316179

# %%
#Division
trial['div'] = trial['foo'] / trial['bar']
trial
# Out:
#         foo       bar       Ali       Abu     Ahmad   bernard       div
# a  0.053032  0.158792  0.137399  0.762381  0.006266  0.326140  0.333968
# b  0.742821  0.272027  0.150535  0.699412  0.264621 -0.347303  2.730687
# c  0.584075  0.531675  0.780485  0.703358  0.467687 -2.316179  1.098558

# %%
# Median for foo
trial['foo'].median()
# Out:
# 0.5840754388562169

# %%
# Max for foo
trial['foo'].max()
# Out:
# 0.7428208400011026

# %% [markdown]
# ### **The Pandas Index Object**

# %%
# Create pandas index
ind = pd.Index([2, 3, 5, 7, 11])
ind
# Out:
# Int64Index([2, 3, 5, 7, 11], dtype='int64')

# %%
# Access individual index
ind[1]
# Out:
# 3

# %%
# Indexing and a step size of 3
ind[::3]
# Out:
# Int64Index([2, 7], dtype='int64')

# %% [markdown]
# ### **Index as ordered set**

# %%
# Index as ordered set
indA = pd.Index([1, 3, 5, 7, 9])
indB = pd.Index([2, 3, 5, 7, 11])

# %%
# Intersection -> '&'
# Returning a new set containing only the elements common to both sets.
indA & indB
# Out:
# <ipython-input-64-180e887522c7>:3: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead.
#   indA & indB
# Int64Index([3, 5, 7], dtype='int64')

# %%
# Union -> '|'
# Combining the elements of both sets, excluding duplicates.
indA | indB
# Out:
# <ipython-input-65-ab36b74b427e>:3: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   indA | indB
# Int64Index([1, 2, 3, 5, 7, 9, 11], dtype='int64')

# %%
# Symmetric difference -> '^'
# Returning a new set containing elements that are unique to each set (not common to both).
indA ^ indB
# Out:
# <ipython-input-66-98cedabd78ef>:3: FutureWarning: Index.__xor__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__xor__.  Use index.symmetric_difference(other) instead.
#   indA ^ indB
# Int64Index([1, 2, 9, 11], dtype='int64')

# %% [markdown]
# # **Data Indexing and Selection**

# %%
# Series as dictionary
data = pd.Series([0.25, 0.5, 0.75, 1],
                 index=['a', 'b', 'c', 'd'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
# Logical testing
'e' in data
# Out:
# False

# %%
# The keys() method is used to retrieve the index labels of the Series
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
# The items() function
# Returns a list of tuples where each tuple contains an index-label
# and its corresponding value from the Series
list(data.items())
# Out:
# [('a', 0.25), ('b', 0.5), ('c', 0.75), ('d', 1.0)]

# %%
# Adding new row of data
# always use bracket
data['e'] = 1.25
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# e    1.25
# dtype: float64

# %%
# Slicing by explicit index - on purpose, use the 'labels'
data['a':'c']
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64

# %% [markdown]
# # **What is implicit indexing?**
# * **Uses the location (numeric) of the indices**
# * **Implicit indexing - the index of an item is <font color='red'>*automatically assigned by the system*</font>, typically based on the order or position of the item.**

# %% [markdown]
# # **What is explicit indexing?**
# * **Explicit indexing is when we <font color='red'>*manually specify or assign the index to each item*</font>.**

# %%
# Slicing by implicit integer index
data[0:2]
# Out:
# a    0.25
# b    0.50
# dtype: float64

# %%
# Masking -> Multiple indexing
data[(data > .3) & (data < .8)]
# Out:
# b    0.50
# c    0.75
# dtype: float64

# %%
# Fancy indexing -> by giving a list
data[['a','e']]
# Out:
# a    0.25
# e    1.25
# dtype: float64

# %% [markdown]
# # **Indexers: loc, & iloc**

# %%
# Create a pandas Series
data = pd.Series(['a', 'b', 'c'], index=[1, 3, 5])
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
# Explicit index - confusing
data[1]
# Out:
# 'a'

# %%
# Implicit index - confusing
data[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %% [markdown]
# ### **loc attribute** allows indexing and slicing that always references the **explicit index**

# %%
# Display the content for data
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
# Explicit index when indexing
data.loc[1]
# Out:
# 'a'

# %%
# Explicit index when slicing - multiple condition
data.loc[1:3]
# Out:
# 1    a
# 3    b
# dtype: object

# %% [markdown]
# ### **iloc attribute** allows indexing and slicing that always references the ***implicit Python-style index***

# %%
# Display data content
data.iloc[1]
# Out:
# 'b'

# %%
# Slicing using iloc
data.iloc[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %% [markdown]
# ### **DataFrame as a dictionary**

# %%
# DataFrame as a dictionary
data = pd.DataFrame({'area': area, 'pop':population})
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
# Explicit indexing
data[['area']]
# Out:
#               area
# California  423967
# Texas       695662
# New York    141297
# Florida     170312
# Illinois    149995

# %%
# Logical testing
data.area is data['area']
# Out:
# True

# %%
# Not always work!
# because we have 'pop' dataset
data.pop is  data['pop']
# Out:
# False

# %%
# Adding a new column
data['density'] = data['pop'] / data['area']
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %% [markdown]
# # **DataFrame as two-dimensional array**

# %%
# Display the content of 'data'
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %%
# Transpose the dataframe
data.T
# Out:
#            California         Texas      New York       Florida      Illinois
# area     4.239670e+05  6.956620e+05  1.412970e+05  1.703120e+05  1.499950e+05
# pop      3.833252e+07  2.644819e+07  1.965113e+07  1.955286e+07  1.288214e+07
# density  9.041393e+01  3.801874e+01  1.390767e+02  1.148061e+02  8.588376e+01

# %%
# Explicit indexing -> single bracket returns Series
data['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
# Display the data content
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %%
# Implicit indexing #when we say implicit, it's integer, use iloc
# Using iloc function - using integer indexing
data.iloc[:3,0:2]
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127

# %%
# Explicit indexing
# Using loc
data.loc[:'Florida',:'pop'] #using loc the last element florida is included
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860

# %%
# Complex - Explicit indexing using loc
# additional condition #data.loc[row,column]
data.loc[data.density>100,['pop','density']]
# Out:
#                pop     density
# New York  19651127  139.076746
# Florida   19552860  114.806121

# %%
# Edit value using Implicit indexing method
# Florida & density -> 115
data.iloc[3,2] = 115 #changes made is permanent
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  115.000000
# Illinois    149995  12882135   85.883763

# %% [markdown]
# # **Operating on Data in Pandas**

# %% [markdown]
# ### **Index alignment in Series**

# %%
# Create some data
area = pd.Series({'Alaska': 1723337, 'Texas': 695662,
                  'California': 423967}, name='area')
population = pd.Series({'California': 38332521, 'Texas': 26448193,
                        'New York': 19651127}, name='population')

# %%
# Compute the population density
population / area
# Out:
# Alaska              NaN
# California    90.413926
# New York            NaN
# Texas         38.018740
# dtype: float64

# %%
# Display the content of area
area
# Out:
# Alaska        1723337
# Texas          695662
# California     423967
# Name: area, dtype: int64

# %%
# Display content of population
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Name: population, dtype: int64

# %%
# Union of index -> '|'
area.index | population.index
# Out:
# <ipython-input-113-1fb64d670202>:2: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   area.index | population.index
# Index(['Alaska', 'California', 'New York', 'Texas'], dtype='object')

# %% [markdown]
# # **Index alignment in DataFrame**

# %%
# Create some data
rng = np.random.RandomState(50)
A = pd.DataFrame(rng.randint(0, 20, (2,2)),
                 columns=list('AB'))
A
# Out:
#     A   B
# 0  16   0
# 1  11  13

# %%
# Create some data
rng = np.random.RandomState(100)
B = pd.DataFrame(rng.randint(0, 10, (3,3)),
                 columns=list('BAC'))
B
# Out:
#    B  A  C
# 0  8  8  3
# 1  7  7  0
# 2  4  2  5

# %%
# Summation
A + B
# Out:
#       A     B   C
# 0  24.0   8.0 NaN
# 1  18.0  20.0 NaN
# 2   NaN   NaN NaN

# %% [markdown]
# # **Pandas DataFrame: stack() function**
# * The ***stack()*** function is used to **stack the prescribed level(s) from <font color=red>*columns to index*</font>.**
# * For more information, please visit this website: https://tinyurl.com/mt27xnk9
# * **change from wide format to long format**

# %% [markdown]
# ![Stacking.png](data:image/png;base64,...)

# %%
# display content of A
A
# Out:
#     A   B
# 0  16   0
# 1  11  13

# %%
# transforming the DataFrame A by stacking its columns to create a new Series
A.stack()
# Out:
# 0  A    16
#    B     0
# 1  A    11
#    B    13
# dtype: int64

# %%
# Getting the median
fill = A.stack().median()
fill
# Out:
# 12.0

# %%
# summation
A+B
# Out:
#       A     B   C
# 0  24.0   8.0 NaN
# 1  18.0  20.0 NaN
# 2   NaN   NaN NaN

# %%
# Fill every missing value with the above median value
# Very confusing
print(A)
print('\n............\n')
print(B)
print('\n............\n')
A.add(B, fill_value = fill)
# Out:
#     A   B
# 0  16   0
# 1  11  13
#
# ............
#
#    B  A  C
# 0  8  8  3
# 1  7  7  0
# 2  4  2  5
#
# ............
#       A     B     C
# 0  24.0   8.0  15.0
# 1  18.0  20.0  12.0
# 2  14.0  16.0  17.0

# %% [markdown]
# # **Operations Between DataFrame and Series**

# %%
# Create an array
rng = np.random.RandomState(100)
A = rng.randint(10, size=(3, 4))
A
# Out:
# array([[8, 8, 3, 7],
#        [7, 0, 4, 2],
#        [5, 2, 2, 2]])

# %%
# Substraction
A - A[0]
# Out:
# array([[ 0,  0,  0,  0],
#        [-1, -8,  1, -5],
#        [-3, -6, -1, -5]])

# %%
# Create a pandas dataframe
df = pd.DataFrame(A, columns=list('QRST'))
df
# Out:
#    Q  R  S  T
# 0  8  8  3  7
# 1  7  0  4  2
# 2  5  2  2  2

# %%
# Substraction using implicit indexing
# Using iloc function
df - df.iloc[0]
# Out:
#    Q  R  S  T
# 0  0  0  0  0
# 1 -1 -8  1 -5
# 2 -3 -6 -1 -5

# %%
# Extract information
df['R']
# Out:
# 0    8
# 1    0
# 2    2
# Name: R, dtype: int64

# %%
# Another way
# Subtraction along the rows
df.subtract(df['R'],axis = 0)
# Out:
#    Q  R  S  T
# 0  0  0 -5 -1
# 1  7  0  4  2
# 2  3  0  0  0

# %% [markdown]
# # **Dropping null values**

# %%
# Create a pandas DataFrame
df = pd.DataFrame([[1, np.nan, 2],
                  [2, 3, 5],
                  [np.nan, 4, 6]])
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
# dropna() removes NA values - row wise
# Cannot drop single values from a DataFrame
df.dropna(axis=0) #or df.dropna() -> same output
# Out:
#      0    1  2
# 1  2.0  3.0  5

# %%
# Drops all columns containing a null value
# column wise
df.dropna(axis = 1)
# Out:
#    2
# 0  2
# 1  5
# 2  6

# %%
# Assign missing data
df[3] = np.nan

# %%
# Display updated df content
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
# how='all' & how='any'
# how='all' will only drop rows/columns that are all null values
df.dropna(axis = 1, how = 'all')
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
#how = 'any
df.dropna( axis = 1, how ='any')
# Out:
#    2
# 0  2
# 1  5
# 2  6

# %% [markdown]
# # ***thresh*** parameter lets us specify a ***minimum number of non-null values*** for the row/column to be kept:

# %%
# Display df content
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
# Minimum number of non-null values for the row/column to be kept
# thresh=3
df.dropna(axis=0, thresh=3)
# Out:
#      0    1  2   3
# 1  2.0  3.0  5 NaN

# %%
# Create a pandas series
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
# fill na with 0
data.fillna(0)
# Out:
# a    1.0
# b    0.0
# c    2.0
# d    0.0
# e    3.0
# dtype: float64

# %% [markdown]
# # ***fillna using some permutation***

# %% [markdown]
# # ***ffill***: forward-fill; propagate the previous value forward

# %%
# Forward fill
data.fillna(method='ffill')
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %% [markdown]
# # **Backward fill**

# %%
# backward fill
data.fillna(method='bfill')
# Out:
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %% [markdown]
# The ***NA*** value remains if a previous value is not available during a forward fill.

# %%
# Display content for df
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
# NA value remains if a previous value is not available during a forward fill
# axis=1
df.fillna(method='ffill', axis=1)
# Out:
#      0    1    2    3
# 0  1.0  1.0  2.0  2.0
# 1  2.0  3.0  5.0  5.0
# 2  NaN  4.0  6.0  6.0

# %% [markdown]
# # **Pandas MultiIndex**

# %% [markdown]
# # **Hierarchical Indexing: incorporate multiple index levels within a single index**

# %%
# Hierarchical Indexing - multiple indexing
index = [('California', 2000), ('California', 2010),
         ('New York', 2000), ('New York', 2010),
         ('Texas', 2000), ('Texas', 2010)]
populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]
pop = pd.Series(populations, index=index)
pop
# Out:
# (California, 2000)    33871648
# (California, 2010)    37253956
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# (Texas, 2000)         20851820
# (Texas, 2010)         25145561
# dtype: int64

# %%
# Slicing
pop[('California',2010):('Texas',2000)]
# Out:
# (California, 2010)    37253956
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# (Texas, 2000)         20851820
# dtype: int64

# %%
# Slicing - confusing and messy
pop[[i for i in pop.index if i[1] == 2010]]
# Out:
# (California, 2010)    37253956
# (New York, 2010)      19378102
# (Texas, 2010)         25145561
# dtype: int64

# %% [markdown]
# # **The Better Way: Pandas MultiIndex**

# %%
# Create a multi-index from the tuples
index = pd.MultiIndex.from_tuples(index)
index
# Out:
# MultiIndex([('California', 2000),
#             ('California', 2010),
#             (  'New York', 2000),
#             (  'New York', 2010),
#             (     'Texas', 2000),
#             (     'Texas', 2010)],
#            )

# %%
# display original content of pop
pop
# Out:
# (California, 2000)    33871648
# (California, 2010)    37253956
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# (Texas, 2000)         20851820
# (Texas, 2010)         25145561
# dtype: int64

# %%
# Re-index series with MultiIndex
# Blank entry indicates the same value as the line above it.
pop = pop.reindex(index)
pop
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
# Access all data for which the second index is 2010
pop[:,2010]
# Out:
# California    37253956
# New York      19378102
# Texas         25145561
# dtype: int64

# %% [markdown]
# # **MultiIndex as extra dimension**

# %%
# display original pop content
pop
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
# Convert a multiple indexed Pandas Series into a conventionally indexed DataFrame
# unstack() -> change back to wide format
pop_df = pop.unstack()
pop_df
# Out:
#                 2000      2010
# California  33871648  37253956
# New York    18976457  19378102
# Texas       20851820  25145561

# %%
# stack() method provides the opposite operation
pop_df.stack()
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
# display original pop_df
pop_df
# Out:
#                     total  under18
# California 2000  33871648  9267089
#            2010  37253956  9284094
# New York   2000  18976457  4687374
#            2010  19378102  4318033
# Texas      2000  20851820  5906301
#            2010  25145561  6879014

# %%
# Adding another column
pop_df = pd.DataFrame({'total': pop,
                       'under18': [9267089, 9284094,
                                   4687374, 4318033,
                                   5906301, 6879014]})

# %%
# display original pop content
# multi index data
pop
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
# Display pop_df
pop_df
# Out:
#                     total  under18
# California 2000  33871648  9267089
#            2010  37253956  9284094
# New York   2000  18976457  4687374
#            2010  19378102  4318033
# Texas      2000  20851820  5906301
#            2010  25145561  6879014

# %%
# Compute the fraction of people under 18 by year
(pop_df['under18'] / pop_df['total']).unstack()
# Out:
#                 2000      2010
# California  0.273594  0.249211
# New York    0.247010  0.222831
# Texas       0.283251  0.273568

# %% [markdown]
# # **Methods of MultiIndex Creation**

# %%
# Pass a list of two or more index arrays
df = pd.DataFrame(np.random.rand(4, 2),
                  index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
                  columns=['data1', 'data2'])
df
# Out:
#         data1     data2
# a 1  0.549785  0.661737
#   2  0.879158  0.941273
# b 1  0.652455  0.038082
#   2  0.517199  0.253695

# %%
# Pass a dictionary with appropriate tuples as keys
data = {('California', 2000): 33871648,
        ('California', 2010): 37253956,
        ('Texas', 2000): 20851820,
        ('Texas', 2010): 25145561,
        ('New York', 2000): 18976457,
        ('New York', 2010): 19378102}
pd.Series(data)
# Out:
# California  2000    33871648
#             2010    37253956
# Texas       2000    20851820
#             2010    25145561
# New York    2000    18976457
#             2010    19378102
# dtype: int64

# %%
# Display pop content
pop
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %% [markdown]
# # **MultiIndex level names**

# %%
# Name the levels of the MultiIndex
pop.index.names = ['state', 'year']
pop
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
# Hierarchical indices and columns
index = pd.MultiIndex.from_product([[2013, 2014], [1, 2]],
                                   names=['year', 'visit'])
columns = pd.MultiIndex.from_product([['Bob', 'Guido', 'Sue'], ['HR', 'Temp']],
                                     names=['subject', 'type'])

# Mock some data
data = np.round(np.random.randn(4, 6), 1)
data[:, ::2] *= 10 # in-place multiplication operation; multiplies each element selected by the slicing operation by 10 and updates the original array
data += 37

# Create the DataFrame
health_data = pd.DataFrame(data, index=index, columns=columns)
health_data
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      30.0  38.2  28.0  38.4  49.0  37.1
#      2      36.0  37.7  33.0  38.5  23.0  37.4
# 2014 1      33.0  36.9  33.0  38.6  55.0  36.1
#      2      48.0  36.2  31.0  37.2  30.0  36.8

# %%
# Slicing by the person's name
# explicit indexing by using label
health_data['Guido']
# Out:
# type          HR  Temp
# year visit
# 2013 1      28.0  38.4
#      2      33.0  38.5
# 2014 1      33.0  38.6
#      2      31.0  37.2

# %% [markdown]
# # **Indexing and Slicing a MultiIndex**

# %%
# Display pop content
pop
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
# Access single elements by indexing with multiple terms
# complete slicing
pop['California',2000]
# Out:
# 33871648

# %%
# Partial slicing
# using loc function
pop.loc['California']
# Out:
# year
# 2000    33871648
# 2010    37253956
# dtype: int64

# %%
# Partial slicing
pop.loc['California':'New York']
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# dtype: int64

# %%
# Partial indexing/slicing
pop[:, 2000]
# Out:
# state
# California    33871648
# New York      18976457
# Texas         20851820
# dtype: int64

# %%
# Selection based on Boolean masks
# condition to meet
pop[pop>22000000]
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# Texas       2010    25145561
# dtype: int64

# %%
# Selection based on fancy indexing
pop[['California','Texas']]
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %% [markdown]
# # **Multiple indexed DataFrames**

# %%
# Display health_data
health_data
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      30.0  38.2  28.0  38.4  49.0  37.1
#      2      36.0  37.7  33.0  38.5  23.0  37.4
# 2014 1      33.0  36.9  33.0  38.6  55.0  36.1
#      2      48.0  36.2  31.0  37.2  30.0  36.8

# %%
# Extract Guido's heart rate
health_data['Guido','HR']
# Out:
# year  visit
# 2013  1        28.0
#       2        33.0
# 2014  1        33.0
#       2        31.0
# Name: (Guido, HR), dtype: float64

# %%
# Using the iloc indexer
health_data.iloc[:2,:2]
# Out:
# subject      Bob
# type          HR  Temp
# year visit
# 2013 1      30.0  38.2
#      2      36.0  37.7

# %%
# Passed a tuple of multiple indices
# using loc -> explicit indexing
health_data.loc[:,('Bob','HR')]
# Out:
# year  visit
# 2013  1        30.0
#       2        36.0
# 2014  1        33.0
#       2        48.0
# Name: (Bob, HR), dtype: float64

# %%
# Display health_data content
print(health_data)
print('\n---------------\n')

# Indexing using IndexSlice
idx = pd.IndexSlice
health_data.loc[idx[:,1],idx[:,'HR']]
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      30.0  38.2  28.0  38.4  49.0  37.1
#      2      36.0  37.7  33.0  38.5  23.0  37.4
# 2014 1      33.0  36.9  33.0  38.6  55.0  36.1
#      2      48.0  36.2  31.0  37.2  30.0  36.8
#
# ---------------
# subject      Bob Guido   Sue
# type          HR    HR    HR
# year visit
# 2013 1      30.0  28.0  49.0
# 2014 1      33.0  33.0  55.0

# %% [markdown]
# # **Stacking and unstacking indices**

# %%
# Display pop content
pop
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
# Convert a dataset from a stacked multi-index to a simple two-dimensional representation
# level = 0 -> based on state
pop.unstack(level=0)
# Out:
# state  California  New York     Texas
# year
# 2000     33871648  18976457  20851820
# 2010     37253956  19378102  25145561

# %%
# Unstack based on level = 1 -> year
pop.unstack(level=1)
# Out:
# year            2000      2010
# state
# California  33871648  37253956
# New York    18976457  19378102
# Texas       20851820  25145561

# %%
# Opposite of unstack() is stack()
pop.unstack().stack()
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %% [markdown]
# # **Index setting and resetting**

# %%
# Display pop content
pop
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
# Reset the index
pop_flat = pop.reset_index(name = 'population')
pop_flat
# Out:
#         state  year  population
# 0  California  2000    33871648
# 1  California  2010    37253956
# 2    New York  2000    18976457
# 3    New York  2010    19378102
# 4       Texas  2000    20851820
# 5       Texas  2010    25145561

# %%
# Build multi index
pop_flat.set_index(['state','year'])
# Out:
#                  population
# state      year
# California 2000    33871648
#            2010    37253956
# New York   2000    18976457
#            2010    19378102
# Texas      2000    20851820
#            2010    25145561

# %% [markdown]
# # **Data Aggregations on Multi-Indices**
# * Pandas has built-in data aggregation methods, such as ***mean(), sum(), and max()***

# %%
# Display health_data
health_data
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      30.0  38.2  28.0  38.4  49.0  37.1
#      2      36.0  37.7  33.0  38.5  23.0  37.4
# 2014 1      33.0  36.9  33.0  38.6  55.0  36.1
#      2      48.0  36.2  31.0  37.2  30.0  36.8

# %%
# Aggregate average measurements for the two visits each year
data_mean = health_data.groupby('year').mean()
data_mean
# Out:
# subject   Bob        Guido          Sue
# type       HR   Temp    HR   Temp    HR   Temp
# year
# 2013     33.0  37.95  30.5  38.45  36.0  37.25
# 2014     40.5  36.55  32.0  37.90  42.5  36.45

# %%
# Take the mean among levels on the columns
data_mean.groupby('type',axis=1).mean()
# Out:
# type         HR       Temp
# year
# 2013  33.166667  37.883333
# 2014  38.333333  36.966667

# %% [markdown]
# # **Good Luck and See you all soon!!!** 😀
